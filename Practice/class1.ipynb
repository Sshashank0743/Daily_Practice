# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
print(len(keyword.kwlist))
# Out:
# 35

# %%
for i in range(1,5):
    print(i)
    print(1+1)
# Out:
# 1
# 2
# 2
# 2
# 3
# 2
# 4
# 2

# %%
int1 = 10
int2 = 25
print(id(int1))
print(id(int2))
# Out:
# 140728528743128
# 140728528743608

# %%
variable = 20 + 5j
print("Is ", variable, " is complex variable? ", isinstance(variable, complex))
# Out:
# Is  (20+5j)  is complex variable?  True

# %%
str1 = "Today is christmas day and there is no holiday"
print("The first character of str1 is: ", str1[0])
# Out:
# The first character of str1 is:  T

# %%
print(str1[6:18])
print(str1[-6])
# Out:
# is christmas
# o

# %%
mylist = ["apple", 2, "has", "been", "sold", "out"]
print(mylist)
# Out:
# ['apple', 2, 'has', 'been', 'sold', 'out']

# %%
mylist[1] = 3
print(mylist)
# Out:
# ['apple', 3, 'has', 'been', 'sold', 'out']

# %%
mylist.remove(3)
print(mylist)
# Out:
# ['apple', 'has', 'been', 'sold', 'out']

# %%
mylist.pop(1)
print(mylist)
# Out:
# ['apple', 'been', 'sold', 'out']

# %%
mydict = {"key1":"add", "key2":"sub", "key3":200}
print(mydict)
# Out:
# {'key1': 'add', 'key2': 'sub', 'key3': 200}

# %%
mydict["key2"] = 100
print(mydict)
# Out:
# {'key1': 'add', 'key2': 100, 'key3': 200}

# %%
mydict["key4"] = 300
print(mydict)
# Out:
# {'key1': 'add', 'key2': 100, 'key3': 200, 'key4': 300}

# %%
del mydict["key3"]
print(mydict)
# Out:
# {'key1': 'add', 'key2': 100, 'key4': 300}

# %%
int('5')
# Out:
# 5

# %%
int('5.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 int('5.5')
#
# ValueError: invalid literal for int() with base 10: '5.5'

# %%
float('5')
# Out:
# 5.0

# %%
float('5.0')
# Out:
# 5.0

# %%
float('.5')
# Out:
# 0.5

# %%
float('5.5')
# Out:
# 5.5

# %%
myString = 'txt1' + '20' + 'txt2'
print(myString)
# Out:
# txt120txt2

# %%
myString = 'txt1' + 20 + 'txt2'
print(myString)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 myString = 'txt1' + 20 + 'txt2'
#       2 print(myString)
#
# TypeError: can only concatenate str (not "int") to str

# %%
myString = 'txt1 ' + str(20) + ' txt2'
print(myString)
# Out:
# txt1 20 txt2

# %%
myList = ['a', 'a', 'b', 'c', 'c', 'd']
print(type(myList))
print(myList)
# Out:
# <class 'list'>
# ['a', 'a', 'b', 'c', 'c', 'd']

# %%
myList = ['a', 'a', 'b', 'c', 'c', 'd']
mySet = set(myList)
print(type(mySet))
print(mySet)
# Out:
# <class 'set'>
# {'b', 'd', 'c', 'a'}

# %%
mySTring1 = ("This is my first testing string")
print(type(mySTring1))
print(mySTring1)
# Out:
# <class 'str'>
# This is my first testing string

# %%
strTolist = list(mySTring)
print(type(strTolist))
print(strTolist)
# Out:
# <class 'list'>
# ['T', 'h', 'i', 's', ' ', 'i', 's', ' ', 'm', 'y', ' ', 'f', 'i', 'r', 's', 't', ' ', 't', 'e', 's', 't', 'i', 'n', 'g', ' ', 's', 't', 'r', 'i', 'n', 'g']
